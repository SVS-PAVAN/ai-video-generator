# %% [markdown]
# <a href="https://colab.research.google.com/github/SVS-PAVAN/ai-video-generator/blob/test01/test01_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
